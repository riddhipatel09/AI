# %% [markdown]
# <a href="https://colab.research.google.com/github/riddhipatel09/AI/blob/main/customer-feedback%20using%20sentiment%20analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install textblob
# !pip install matplotlib
# !pip install pandas

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
print(df.columns)
# Out:
# Index(['Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score'], dtype='object')

# %%
df = pd.read_csv('/content/sentiment-analysis.csv', quotechar='"', engine='python')

# Apply cleaning and sentiment analysis
df['clean_text'] = df['Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score'].apply(clean_text)
df['sentiment'] = df['Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score'].apply(get_sentiment)

# Display results
print(df[['Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score', 'clean_text', 'sentiment']])

# Optional: visualize sentiment counts
sentiment_counts = df['sentiment'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(sentiment_counts.index, sentiment_counts.values, color=['green','blue','red'])
plt.title("Customer Feedback Sentiment Analysis")
plt.xlabel("Sentiment")
plt.ylabel("Number of Feedbacks")
plt.show()
# Out:
#    Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score  \
# 0   "I love this product!", Positive, Twitter, 202...
# 1   "The service was terrible.", Negative, Yelp Re...
# 2   "This movie is amazing!", Positive, IMDb, 2023...
# 3   "I'm so disappointed with their customer suppo...
# 4   "Just had the best meal of my life!", Positive...
# ..                                                ...
# 91  "Just had the most amazing vacation! I can't w...
# 92  "The food at this restaurant was awful. Never ...
# 93  "I can't stop listening to this song. It's my ...
# 94  "Their website is so confusing and poorly desi...
# 95  "I had an incredible experience at the theme p...
#
#                                            clean_text sentiment
# 0   I love this product Positive Twitter 2023 06 1...  positive
# 1   The service was terrible Negative Yelp Reviews...  negative
# 2   This movie is amazing Positive IMDb 2023 06 15...  positive
# ...

# %%
print("Sample of DataFrame:")
display(df[['Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score', 'clean_text', 'sentiment']].head())

print("\nSentiment Distribution:")
print(sentiment_counts)

# The plot was already generated in the previous step, so no need to regenerate it here.
# We will just confirm the observations based on the previous output.
print("\nBar plot observation:")
print("The bar plot visualizes the counts of positive and negative sentiments, accurately reflecting the sentiment distribution shown in the sentiment_counts output.")
# Out:
# Sample of DataFrame:
#   Text, Sentiment, Source, Date/Time, User ID, Location, Confidence Score  \
# 0  "I love this product!", Positive, Twitter, 202...
# 1  "The service was terrible.", Negative, Yelp Re...
# 2  "This movie is amazing!", Positive, IMDb, 2023...
# 3  "I'm so disappointed with their customer suppo...
# 4  "Just had the best meal of my life!", Positive...
#
#                                           clean_text sentiment
# 0  I love this product Positive Twitter 2023 06 1...  positive
# 1  The service was terrible Negative Yelp Reviews...  negative
# 2  This movie is amazing Positive IMDb 2023 06 15...  positive
# 3  I m so disappointed with their customer suppor...  negative
# 4  Just had the best meal of my life Positive Tri...  positive
# Sentiment Distribution:
# sentiment
# positive    52
# negative    44
# Name: count, dtype: int64
#
# Bar plot observation:
# ...
